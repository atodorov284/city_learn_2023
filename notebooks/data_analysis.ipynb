# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../data/citylearn_challenge_2023_phase_2_local_evaluation/building_1.csv')

# %%
df
# Out:
#      Month  Hour  Day Type  Daylight Savings Status  Indoor Temperature (C)  \
# 0        6     1         5                        0               23.098652
# 1        6     2         5                        0               22.234742
# 2        6     3         5                        0               22.223061
# 3        6     4         5                        0               22.222251
# 4        6     5         5                        0               22.222236
# ..     ...   ...       ...                      ...                     ...
# 715      6    20         6                        0               24.468618
# 716      6    21         6                        0               24.444859
# 717      6    22         6                        0               24.444464
# 718      6    23         6                        0               24.444453
# 719      6    24         6                        0               21.812446
#
#      Average Unmet Cooling Setpoint Difference (C)  \
# ...
